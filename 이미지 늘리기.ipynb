# %%
pwd
# Out:
# '/Users/imingyu/python/dl/eyedisease/archive(1)prepro'

# %%
import cv2
import glob
import pandas as pd

# %%
load_path = 'preprocessed_images'
save_path = 'ex'

# %%
ori_img = glob.glob('preprocessed_images/*')

# %%
img_li = []
for li in enumerate(ori_img):
    sp = ori_img[0].split('/')[1]
    img_li.append(sp)

# %%
full_df = pd.read_csv('full_df.csv')

# %%
full_df
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        2           42        Male     2_left.jpg     2_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 4        5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 6387  4686           63        Male  4686_left.jpg  4686_right.jpg
# 6388  4688           42        Male  4688_left.jpg  4688_right.jpg
# 6389  4689           54        Male  4689_left.jpg  4689_right.jpg
# 6390  4690           57        Male  4690_left.jpg  4690_right.jpg
# 6391  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 0                                              cataract
# ...

# %%
import cv2
 
img = cv2.imread(ori_img, cv2.IMREAD_COLOR)
 
img90 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE) # 시계방향으로 90도 회전
img180 = cv2.rotate(img, cv2.ROTATE_180) # 180도 회전
img270 = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE) # 반시계방향으로 90도 회전 
                                                         # = 시계방향으로 270도 회전
 
cv2.imshow('rotate90', img90)
cv2.imshow('rotate180', img180)
cv2.imshow('rotate270', img270)
 
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 3>()
#       1 import cv2
# ----> 3 img = cv2.imread(ori_img, cv2.IMREAD_COLOR)
#       5 img90 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE) # 시계방향으로 90도 회전
#       6 img180 = cv2.rotate(img, cv2.ROTATE_180) # 180도 회전
#
# TypeError: Can't convert object to 'str' for 'filename'
